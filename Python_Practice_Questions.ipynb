# %% [markdown]
# # Python Practice Questions

# %% [markdown]
# ## Q1. Student Information
#
# Create variables to store:
# - Student Name
# - Age
# - Percentage
# - Passed (Boolean)
#
# Print all the information in a proper format.

# %%
# Write your solution here

# %% [markdown]
# ## Q2. Personal Details
#
# Store your name, city, age, and height in variables and print them in one sentence.

# %%
# Write your solution here

# %% [markdown]
# ## Q3. Arithmetic Calculator
#
# Create two variables and print Sum, Difference, Product, Division, Floor Division, Modulus and Power.

# %%
# Write your solution here

# %% [markdown]
# ## Q4. Data Type Checker
#
# Create variables of type int, float, string, bool, list, tuple, set and dictionary. Print each value and its data type.

# %%
# Write your solution here

# %% [markdown]
# ## Q5. Type Casting
#
# Create age='22' and salary='35000.50'. Convert them into appropriate data types and print their types.

# %%
# Write your solution here

# %% [markdown]
# ## Q6. String Operations
#
# Given language='Python Programming', print Length, Uppercase, Lowercase, First character and Last character.

# %%
# Write your solution here

# %% [markdown]
# ## Q7. Boolean Practice
#
# Create two numbers. Check greater than, equal to and less than or equal to.

# %%
# Write your solution here

# %% [markdown]
# ## Q8. Even or Odd
#
# Store a number and print whether it is Even or Odd.

# %%
# Write your solution here

# %% [markdown]
# ## Q9. Largest Number
#
# Store three numbers and print the largest.

# %%
# Write your solution here

# %% [markdown]
# ## Q10. Marks and Grade
#
# Assign grade using marks:
# 90-100:A
# 75-89:B
# 60-74:C
# Below 60:Fail

# %%
# Write your solution here

# %% [markdown]
# ## Q11. List Practice
#
# Create a list of five fruits. Print complete list, first item, last item and total items.

# %%
# Write your solution here

# %% [markdown]
# ## Q12. Tuple Practice
#
# Create a tuple of five numbers. Print first, last and length.

# %%
# Write your solution here

# %% [markdown]
# ## Q13. Set Practice
#
# Create a set with duplicate values. Print it and explain why duplicates disappeared.

# %%
# Write your solution here

# %% [markdown]
# ## Q14. Dictionary Practice
#
# Create a student dictionary with Name, Roll Number, Branch and Percentage. Print all values.

# %%
# Write your solution here

# %% [markdown]
# ## Q15. Student Result
#
# Print Pass/Fail and Scholarship eligibility (marks >=75).

# %%
# Write your solution here

# %% [markdown]
# ## Q16. Electricity Bill
#
# Calculate electricity bill using slab rates:
# First 100 units: $2/unit
# Next 100: $4/unit
# Remaining: $6/unit.

# %%
# Write your solution here

# %% [markdown]
# ## Q17. Shopping Bill
#
# Store prices of five products in a list. Find total, average, highest and lowest price.

# %%
# Write your solution here

# %% [markdown]
# ## Q18. Employee Information
#
# Create employee dictionary. Print details and classify as Senior if salary > $50,000 else Junior.

# %%
# Write your solution here

# %% [markdown]
# ## Q19. Password Validator
#
# Minimum 8 characters and at least one digit. Print Strong or Weak Password.

# %%
# Write your solution here

# %% [markdown]
# ## Q20. Voting Eligibility
#
# Store Name, Age and Citizenship(True/False). Print Eligible/Not Eligible.

# %%
# Write your solution here

# %% [markdown]
# ## Q21. Cricket Scores
#
# Create list of five match scores. Print highest, lowest, average and total.

# %%
# Write your solution here

# %% [markdown]
# ## Q22. Library Book Record
#
# Create dictionary with Book Name, Author, Price and Available(True/False).

# %%
# Write your solution here

# %% [markdown]
# ## Q23. Mobile Specifications
#
# Create dictionary with Brand, RAM, Storage and Price. Classify Premium/Budget.

# %%
# Write your solution here

# %% [markdown]
# ## Q24. List Comparison
#
# Create two lists. Print common elements and total unique elements using set.

# %%
# Write your solution here

# %% [markdown]
# ## Q25. Student Attendance
#
# If attendance >=75% print Allowed in Exam else Not Allowed.

# %%
# Write your solution here

# %% [markdown]
# ## Q26. Student Management System
#
# Store student details and marks of five subjects. Calculate Total, Percentage and Grade.

# %%
# Write your solution here

# %% [markdown]
# ## Q27. ATM System
#
# Store Account Holder, Balance and Withdrawal Amount. Print remaining balance or Insufficient Balance.

# %%
# Write your solution here

# %% [markdown]
# ## Q28. Shopping Management System
#
# Store Customer Name, Product List, Quantity and Price. Calculate bill and 10% discount if bill exceeds $1,000.

# %%
# Write your solution here

# %% [markdown]
# ## Q29. Employee Salary System
#
# Calculate HRA=20%, DA=10%, Gross Salary and classify employee.

# %%
# Write your solution here

# %% [markdown]
# ## Q30. School Result System
#
# Store student details, calculate Total, Percentage, Grade and Pass/Fail. Print Outstanding/Excellent/Good/Needs Improvement.

# %%
# Write your solution here
